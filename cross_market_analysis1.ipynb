# %%
import requests
import time

all_records = []

# Loop through pages 1 to 5
for page_number in range(1, 6):
    # Use f-string to insert the page_number into the URL
    url = f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&page={page_number}&sparkline=False"

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()  # Convert the response to a list of dictionaries
        all_records.extend(data) # Add the new list of coins to our main list
        print(f"Page {page_number} collected. Total coins: {len(all_records)}")
    else:
        print(f"Failed to fetch Page {page_number}. Error: {response.status_code}")
        break

    # Pro-tip: CoinGecko has rate limits. Adding a tiny sleep prevents getting blocked.
    time.sleep(1)

print(f"Successfully collected {len(all_records)} coin records!")
# Out:
# Page 1 collected. Total coins: 250
# Page 2 collected. Total coins: 500
# Page 3 collected. Total coins: 750
# Failed to fetch Page 4. Error: 429
# Successfully collected 750 coin records!

# %%
records = []
for i in all_records:
    records.append({
        'id': i['id'], 
        'symbol': i['symbol'], 
        'name': i['name'], 
        'current_price': i['current_price'], 
        'market_cap': i['market_cap'], 
        'market_cap_rank': i['market_cap_rank'], 
        'total_volume': i['total_volume'],
        'circulating_supply': i['circulating_supply'], 
        'total_supply': i['total_supply'], 
        'ath': i['ath'], 
        'atl': i['atl'], 
        'last_updated': i['last_updated']
    })
records
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'current_price': 6045532,
#   'market_cap': 120852395422070,
#   'market_cap_rank': 1,
#   'total_volume': 4068008156368,
#   'circulating_supply': 19987456.0,
#   'total_supply': 19987456.0,
#   'ath': 11187013,
#   'atl': 3993.42,
#   'last_updated': '2026-02-11T07:03:20.755Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'current_price': 176448,
#   'market_cap': 21296838227583,
#   'market_cap_rank': 2,
#   'total_volume': 1938983126624,
#   'circulating_supply': 120692569.8584684,
#   'total_supply': 120692569.8584684,
#   'ath': 431946,
#   'atl': 28.13,
#   'last_updated': '2026-02-11T07:03:20.943Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'current_price': 90.51,
#   'market_cap': 16689936562055,
#   'market_cap_rank': 3,
#   'total_volume': 6551301479720,
#   'circulating_supply': 184394018025.3612,
#   'total_supply': 189860955264.5262,
#   'ath': 105.52,
#   'atl': 36.86,
#   'last_updated': '2026-02-11T07:03:27.265Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'current_price': 123.05,
#   'market_cap': 7497239093961,
#   'market_cap_rank': 4,
#   'total_volume': 223450906725,
#   'circulating_supply': 60917315351.0,
#   'total_supply': 99985721048.0,
#   'ath': 313.99,
#   'atl': 0.159343,
#   'last_updated': '2026-02-11T07:03:27.277Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'current_price': 54250,
#   'market_cap': 7397643643204,
#   'market_cap_rank': 5,
#   'total_volume': 111312726490,
#   'circulating_supply': 136359497.93,
#   'total_supply': 136359497.93,
#   'ath': 121422,
#   'atl': 2.58,
#   'last_updated': '2026-02-11T07:03:31.968Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'current_price': 90.56,
#   'market_cap': 6638410671211,
#   'market_cap_rank': 6,
#   'total_volume': 1267218841966,
#   'circulating_supply': 73302136419.47241,
#   'total_supply': 73304546455.02899,
#   'ath': 1327.87,
#   'atl': 65.31,
#   'last_updated': '2026-02-11T07:03:27.219Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'current_price': 7316.13,
#   'market_cap': 4153711389654,
#   'market_cap_rank': 7,
#   'total_volume': 326985453316,
#   'circulating_supply': 567716626.4860677,
#   'total_supply': 620122213.0632802,
#   'ath': 25396,
#   'atl': 38.03,
#   'last_updated': '2026-02-11T07:03:26.996Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'current_price': 24.85,
#   'market_cap': 2354099591344,
#   'market_cap_rank': 8,
#   'total_volume': 48962550185,
#   'circulating_supply': 94720627301.7341,
#   'total_supply': 94721270445.3507,
#   'ath': 36.53,
#   'atl': 0.117589,
#   'last_updated': '2026-02-11T07:03:26.845Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'current_price': 93.43,
#   'market_cap': 1407485365287,
#   'market_cap_rank': 9,
#   'total_volume': 2600794743,
#   'circulating_supply': 15065146581.537,
#   'total_supply': 15065146581.537,
#   'ath': 120.96,
#   'atl': 13.78,
#   'last_updated': '2026-02-11T05:20:08.439Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'current_price': 8.18,
#   'market_cap': 1380185381827,
#   'market_cap_rank': 10,
#   'total_volume': 74922728362,
#   'circulating_supply': 168669383126.5791,
#   'total_supply': 168690843126.5791,
#   'ath': 53.62,
#   'atl': 0.00552883,
#   'last_updated': '2026-02-11T07:03:26.956Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'current_price': 4558.37,
#   'market_cap': 974169658766,
#   'market_cap_rank': 11,
#   'total_volume': 9107092250,
#   'circulating_supply': 213729819.0,
#   'total_supply': 320229819.0,
#   'ath': 5758.63,
#   'atl': 245.71,
#   'last_updated': '2026-02-11T07:03:26.633Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'current_price': 46893,
#   'market_cap': 937559522621,
#   'market_cap_rank': 12,
#   'total_volume': 30526403655,
#   'circulating_supply': 19993140.52165078,
#   'total_supply': 19993409.27165078,
#   'ath': 242198,
#   'atl': 5536.54,
#   'last_updated': '2026-02-11T07:03:26.902Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'current_price': 90.55,
#   'market_cap': 866214388722,
#   'market_cap_rank': 13,
#   'total_volume': 428177875,
#   'circulating_supply': 9566290375.652334,
#   'total_supply': 9566290375.652334,
#   'ath': 92.23,
#   'atl': 79.67,
#   'last_updated': '2026-02-11T07:03:26.644Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'current_price': 23.11,
#   'market_cap': 850283308741,
#   'market_cap_rank': 14,
#   'total_volume': 32236263597,
#   'circulating_supply': 36794311012.29324,
#   'total_supply': 45000000000.0,
#   'ath': 225.26,
#   'atl': 1.38,
#   'last_updated': '2026-02-11T07:03:26.988Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'current_price': 747.95,
#   'market_cap': 689152273188,
#   'market_cap_rank': 15,
#   'total_volume': 119278876,
#   'circulating_supply': 921393276.9,
#   'total_supply': 985239504.0,
#   'ath': 888.26,
#   'atl': 56.97,
#   'last_updated': '2026-02-11T07:03:26.625Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'current_price': 2621.81,
#   'market_cap': 625457979362,
#   'market_cap_rank': 16,
#   'total_volume': 26251860264,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'ath': 5213.52,
#   'atl': 321.88,
#   'last_updated': '2026-02-11T07:03:26.775Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'current_price': 90.43,
#   'market_cap': 581491405811,
#   'market_cap_rank': 17,
#   'total_volume': 7277322716,
#   'circulating_supply': 6430393935.142717,
#   'total_supply': 6430393935.142717,
#   'ath': 92.91,
#   'atl': 78.05,
#   'last_updated': '2026-02-11T07:03:26.759Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'current_price': 30804,
#   'market_cap': 568670119058,
#   'market_cap_rank': 18,
#   'total_volume': 8848303207,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'ath': 72026,
#   'atl': 13.57,
#   'last_updated': '2026-02-11T07:03:26.677Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'current_price': 14.78,
#   'market_cap': 556895919783,
#   'market_cap_rank': 19,
#   'total_volume': 944656340,
#   'circulating_supply': 37711955931.79735,
#   'total_supply': 37711955931.79735,
#   'ath': 17.72,
#   'atl': 5.31,
#   'last_updated': '2026-02-11T07:03:26.725Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'current_price': 751.72,
#   'market_cap': 532345993915,
#   'market_cap_rank': 20,
#   'total_volume': 26792435440,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'ath': 3862.15,
#   'atl': 9.55,
#   'last_updated': '2026-02-11T07:03:27.758Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'current_price': 90.5,
#   'market_cap': 487101322211,
#   'market_cap_rank': 21,
#   'total_volume': 155287307124,
#   'circulating_supply': 5383667513.448098,
#   'total_supply': 5383667513.448098,
#   'ath': 92.17,
#   'atl': 83.75,
#   'last_updated': '2026-02-11T07:03:27.302Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'current_price': 13.91,
#   'market_cap': 455281415566,
#   'market_cap_rank': 22,
#   'total_volume': 9758312238,
#   'circulating_supply': 32726838539.31324,
#   'total_supply': 50001786883.65895,
#   'ath': 58.01,
#   'atl': 0.02966141,
#   'last_updated': '2026-02-11T07:03:26.976Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'current_price': 90.6,
#   'market_cap': 379204317976,
#   'market_cap_rank': 23,
#   'total_volume': 6407588275,
#   'circulating_supply': 4185494804.49468,
#   'total_supply': 4185494804.49468,
#   'ath': 92.29,
#   'atl': 64.85,
#   'last_updated': '2026-02-11T07:03:27.005Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'current_price': 4713.96,
#   'market_cap': 362182058733,
#   'market_cap_rank': 24,
#   'total_volume': 24086712694,
#   'circulating_supply': 76830789.48347135,
#   'total_supply': 76836195.73347135,
#   'ath': 30082,
#   'atl': 72.12,
#   'last_updated': '2026-02-11T07:03:26.820Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'current_price': 90.52,
#   'market_cap': 353764921976,
#   'market_cap_rank': 26,
#   'total_volume': 35565663529,
#   'circulating_supply': 3908124543.645228,
#   'total_supply': 3908124543.645228,
#   'ath': 92.2,
#   'atl': 80.95,
#   'last_updated': '2026-02-11T07:03:27.199Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'current_price': 21376,
#   'market_cap': 352996972832,
#   'market_cap_rank': 25,
#   'total_volume': 29257532485,
#   'circulating_supply': 16511426.7280448,
#   'total_supply': 16511426.7280448,
#   'ath': 211171,
#   'atl': 1342.38,
#   'last_updated': '2026-02-11T07:03:26.754Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'current_price': 8.0,
#   'market_cap': 344117169080,
#   'market_cap_rank': 27,
#   'total_volume': 7405483299,
#   'circulating_supply': 43003138665.45859,
#   'total_supply': 50000000000.0,
#   'ath': 41.81,
#   'atl': 0.703644,
#   'last_updated': '2026-02-11T07:03:26.829Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'current_price': 775.18,
#   'market_cap': 334708795154,
#   'market_cap_rank': 28,
#   'total_volume': 21759923563,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'ath': 10772.35,
#   'atl': 204.63,
#   'last_updated': '2026-02-11T07:03:26.968Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'current_price': 0.930734,
#   'market_cap': 316294142530,
#   'market_cap_rank': 29,
#   'total_volume': 2641550716,
#   'circulating_supply': 339864219379.0761,
#   'total_supply': 1149930169531.519,
#   'ath': 0.989197,
#   'atl': 0.196087,
#   'last_updated': '2026-02-11T07:03:26.714Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'current_price': 0.00052929,
#   'market_cap': 311909781251,
#   'market_cap_rank': 31,
#   'total_volume': 11864650388,
#   'circulating_supply': 589243881085228.2,
#   'total_supply': 589500418260677.5,
#   'ath': 0.00645756,
#   'atl': 4.169e-09,
#   'last_updated': '2026-02-11T07:03:26.974Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'current_price': 81.06,
#   'market_cap': 311710327094,
#   'market_cap_rank': 30,
#   'total_volume': 42531393406,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'ath': 458.6,
#   'atl': 30.36,
#   'last_updated': '2026-02-11T07:03:27.145Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'current_price': 118.33,
#   'market_cap': 289713009355,
#   'market_cap_rank': 32,
#   'total_volume': 7236963767,
#   'circulating_supply': 2448192782.218552,
#   'total_supply': 5153811737.731104,
#   'ath': 689.6,
#   'atl': 38.25,
#   'last_updated': '2026-02-11T07:03:27.083Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'current_price': 6.83,
#   'market_cap': 272112055100,
#   'market_cap_rank': 33,
#   'total_volume': 1366189988,
#   'circulating_supply': 39853717675.41057,
#   'total_supply': 98387046017.4802,
#   'ath': 72.06,
#   'atl': 0.864137,
#   'last_updated': '2026-02-11T07:03:26.756Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'current_price': 9.32,
#   'market_cap': 253976812354,
#   'market_cap_rank': 34,
#   'total_volume': 7994749025,
#   'circulating_supply': 27243802538.151154,
#   'total_supply': 100000000000.0,
#   'ath': 29.22,
#   'atl': 8.91,
#   'last_updated': '2026-02-11T07:03:26.867Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'current_price': 455409,
#   'market_cap': 236740351458,
#   'market_cap_rank': 35,
#   'total_volume': 27900496296,
#   'circulating_supply': 519825.641699,
#   'total_supply': 712747.089,
#   'ath': 514631,
#   'atl': 108167,
#   'last_updated': '2026-02-11T07:03:26.860Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'current_price': 129.19,
#   'market_cap': 224061134303,
#   'market_cap_rank': 36,
#   'total_volume': 730226002,
#   'circulating_supply': 1734401267.76973,
#   'total_supply': 5334385863.412934,
#   'ath': 260.79,
#   'atl': 4.05,
#   'last_updated': '2026-02-11T07:03:26.728Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'current_price': 458266,
#   'market_cap': 210351576106,
#   'market_cap_rank': 37,
#   'total_volume': 22474876239,
#   'circulating_supply': 459009.975,
#   'total_supply': 459009.975,
#   'ath': 516779,
#   'atl': 100361,
#   'last_updated': '2026-02-11T07:03:27.702Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'current_price': 112.5,
#   'market_cap': 187116743746,
#   'market_cap_rank': 38,
#   'total_volume': 8163446549,
#   'circulating_supply': 1664267932.778928,
#   'total_supply': 1664267932.778928,
#   'ath': 4095.22,
#   'atl': 103.91,
#   'last_updated': '2026-02-11T07:03:27.568Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'current_price': 294.07,
#   'market_cap': 186422481753,
#   'market_cap_rank': 39,
#   'total_volume': 10980746078,
#   'circulating_supply': 633923278.1680214,
#   'total_supply': 898908420.0366304,
#   'ath': 3333.06,
#   'atl': 75.81,
#   'last_updated': '2026-02-11T07:03:27.050Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'current_price': 56.32,
#   'market_cap': 183206418069,
#   'market_cap_rank': 40,
#   'total_volume': 2467590571,
#   'circulating_supply': 3252944055.636841,
#   'total_supply': 6219316794.89,
#   'ath': 253.43,
#   'atl': 25.64,
#   'last_updated': '2026-02-11T07:03:26.945Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'current_price': 90.58,
#   'market_cap': 166701999741,
#   'market_cap_rank': 41,
#   'total_volume': None,
#   'circulating_supply': 1840412389.420449,
#   'total_supply': 1840412389.420449,
#   'ath': 92.2,
#   'atl': 83.81,
#   'last_updated': '2026-02-11T06:45:05.747Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'current_price': 90.26,
#   'market_cap': 159005963459,
#   'market_cap_rank': 42,
#   'total_volume': 56483376,
#   'circulating_supply': 1761528348.31948,
#   'total_supply': 1761528348.31948,
#   'ath': 92.45,
#   'atl': 80.47,
#   'last_updated': '2026-02-11T07:03:27.074Z'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'current_price': 209.13,
#   'market_cap': 146389559239,
#   'market_cap_rank': 43,
#   'total_volume': 2628344649,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'ath': 722.65,
#   'atl': 1.081,
#   'last_updated': '2026-02-11T07:03:26.769Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'current_price': 9563.85,
#   'market_cap': 145277863871,
#   'market_cap_rank': 44,
#   'total_volume': 19967919291,
#   'circulating_supply': 15190334.606571734,
#   'total_supply': 16000000.0,
#   'ath': 48387,
#   'atl': 1933.39,
#   'last_updated': '2026-02-11T07:03:27.825Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'current_price': 58.55,
#   'market_cap': 143592980804,
#   'market_cap_rank': 45,
#   'total_volume': 34765416454,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'ath': 213.7,
#   'atl': 8.76,
#   'last_updated': '2026-02-11T07:03:26.886Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'current_price': 90.55,
#   'market_cap': 143048638499,
#   'market_cap_rank': 47,
#   'total_volume': 3223118854,
#   'circulating_supply': 1579822398.455778,
#   'total_supply': 1579822398.455778,
#   'ath': 143.35,
#   'atl': 76.61,
#   'last_updated': '2026-02-11T07:03:26.810Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'current_price': 101.11,
#   'market_cap': 143216750855,
#   'market_cap_rank': 46,
#   'total_volume': 4044.32,
#   'circulating_supply': 1416473350.04677,
#   'total_supply': 1416473350.04677,
#   'ath': 102.4,
#   'atl': 86.89,
#   'last_updated': '2026-02-10T05:42:11.457Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'current_price': 6587.46,
#   'market_cap': 138676468096,
#   'market_cap_rank': 48,
#   'total_volume': 1592808834,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'ath': 22313,
#   'atl': 40.86,
#   'last_updated': '2026-02-11T07:03:27.020Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'current_price': 90.55,
#   'market_cap': 137819791080,
#   'market_cap_rank': 49,
#   'total_volume': 11478584656,
#   'circulating_supply': 1521941230.127497,
#   'total_supply': 1521941230.127497,
#   'ath': 92.15,
#   'atl': 81.72,
#   'last_updated': '2026-02-11T07:03:27.242Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'current_price': 0.00015041,
#   'market_cap': 137807684905,
#   'market_cap_rank': 50,
#   'total_volume': 848510641,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'ath': 0.00031771,
#   'atl': 6.739e-05,
#   'last_updated': '2026-02-11T07:03:26.791Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'current_price': 0.00032047,
#   'market_cap': 134839808372,
#   'market_cap_rank': 51,
#   'total_volume': 25119121393,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'atl': 4.52e-06,
#   'last_updated': '2026-02-11T07:03:27.561Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'current_price': 5.84,
#   'market_cap': 134431933583,
#   'market_cap_rank': 52,
#   'total_volume': 1570018350,
#   'circulating_supply': 23013731871.383068,
#   'total_supply': 23462665147.36596,
#   'ath': 8.62,
#   'atl': 3.12,
#   'last_updated': '2026-02-11T07:03:27.225Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'current_price': 13270.03,
#   'market_cap': 127458543380,
#   'market_cap_rank': 53,
#   'total_volume': 5998627663,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'ath': 62722,
#   'atl': 2535.93,
#   'last_updated': '2026-02-11T07:03:27.284Z'},
#  {'id': 'bfusd',
#   'symbol': 'bfusd',
#   'name': 'BFUSD',
#   'current_price': 90.48,
#   'market_cap': 119418533248,
#   'market_cap_rank': 54,
#   'total_volume': 479601781,
#   'circulating_supply': 1320000000.0,
#   'total_supply': 1320000000.0,
#   'ath': 92.02,
#   'atl': 86.85,
#   'last_updated': '2026-02-11T07:03:27.584Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'current_price': 208.95,
#   'market_cap': 114533360867,
#   'market_cap_rank': 55,
#   'total_volume': 3818272358,
#   'circulating_supply': 548120768.8618584,
#   'total_supply': 548120768.8618584,
#   'ath': 51433,
#   'atl': 187.57,
#   'last_updated': '2026-02-11T07:03:28.237Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'current_price': 730.83,
#   'market_cap': 113635284329,
#   'market_cap_rank': 56,
#   'total_volume': 4120452356,
#   'circulating_supply': 155482411.418631,
#   'total_supply': 155483474.522631,
#   'ath': 12296.58,
#   'atl': 41.44,
#   'last_updated': '2026-02-11T07:03:27.430Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'current_price': 86.81,
#   'market_cap': 111765406036,
#   'market_cap_rank': 57,
#   'total_volume': 12957021709,
#   'circulating_supply': 1287453804.0,
#   'total_supply': 1287479722.0,
#   'ath': 1518.16,
#   'atl': 39.17,
#   'last_updated': '2026-02-11T07:03:26.971Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'current_price': 12.1,
#   'market_cap': 108863817911,
#   'market_cap_rank': 58,
#   'total_volume': 1113415784,
#   'circulating_supply': 8995753899.960905,
#   'total_supply': 13831173860.68032,
#   'ath': 260.4,
#   'atl': 12.08,
#   'last_updated': '2026-02-11T07:03:26.956Z'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'current_price': 21.74,
#   'market_cap': 105819429315,
#   'market_cap_rank': 59,
#   'total_volume': 4284081784,
#   'circulating_supply': 4869330647.0,
#   'total_supply': 10000000000.0,
#   'ath': 181.52,
#   'atl': 6.83,
#   'last_updated': '2026-02-11T07:03:27.092Z'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'Gate',
#   'current_price': 623.38,
#   'market_cap': 103919175936,
#   'market_cap_rank': 60,
#   'total_volume': 140693652,
#   'circulating_supply': 115180573.04885802,
#   'total_supply': 115180573.04885802,
#   'ath': 2235.58,
#   'atl': 19.44,
#   'last_updated': '2026-02-11T07:03:26.840Z'},
#  {'id': 'pump-fun',
#   'symbol': 'pump',
#   'name': 'Pump.fun',
#   'current_price': 0.169306,
#   'market_cap': 99953613113,
#   'market_cap_rank': 61,
#   'total_volume': 8293755627,
#   'circulating_supply': 590000000000.0,
#   'total_supply': 999989199086.5311,
#   'ath': 0.77853,
#   'atl': 0.150889,
#   'last_updated': '2026-02-11T07:03:27.158Z'},
#  {'id': 'kucoin-shares',
#   'symbol': 'kcs',
#   'name': 'KuCoin',
#   'current_price': 727.09,
#   'market_cap': 95939762455,
#   'market_cap_rank': 62,
#   'total_volume': 349381188,
#   'circulating_supply': 132155021.7355671,
#   'total_supply': 142155021.7355671,
#   'ath': 2158.41,
#   'atl': 24.48,
#   'last_updated': '2026-02-11T07:03:26.858Z'},
#  {'id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'name': 'Worldcoin',
#   'current_price': 33.36,
#   'market_cap': 94157961396,
#   'market_cap_rank': 63,
#   'total_volume': 8848509608,
#   'circulating_supply': 2822045061.813433,
#   'total_supply': 10000000000.0,
#   'ath': 971.56,
#   'atl': 28.73,
#   'last_updated': '2026-02-11T07:03:27.036Z'},
#  {'id': 'superstate-short-duration-us-government-securities-fund-ustb',
#   'symbol': 'ustb',
#   'name': 'Superstate Short Duration U.S. Government Securities Fund (USTB)',
#   'current_price': 994.84,
#   'market_cap': 91499876544,
#   'market_cap_rank': 64,
#   'total_volume': None,
#   'circulating_supply': 91974243.622832,
#   'total_supply': 91974243.622832,
#   'ath': 1011.63,
#   'atl': 876.83,
#   'last_updated': '2026-02-11T07:00:13.927Z'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'current_price': 90.51,
#   'market_cap': 91135162697,
#   'market_cap_rank': 65,
#   'total_volume': 266190195,
#   'circulating_supply': 1007229750.0,
#   'total_supply': 1010132503.0,
#   'ath': 92.2,
#   'atl': 72.35,
#   'last_updated': '2026-02-11T07:03:27.307Z'},
#  {'id': 'hash-2',
#   'symbol': 'hash',
#   'name': 'Provenance Blockchain',
#   'current_price': 1.67,
#   'market_cap': 90983449592,
#   'market_cap_rank': 66,
#   'total_volume': 9433147,
#   'circulating_supply': 54482437395.0,
#   'total_supply': 100000000000.0,
#   'ath': 5.31,
#   'atl': 0.877643,
#   'last_updated': '2026-02-11T07:03:26.987Z'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'current_price': 6129.68,
#   'market_cap': 89133879283,
#   'market_cap_rank': 67,
#   'total_volume': 1444466510,
#   'circulating_supply': 14544176.164081175,
#   'total_supply': 14612493.0,
#   'ath': 31427,
#   'atl': 15.06,
#   'last_updated': '2026-02-11T07:03:28.063Z'},
#  {'id': 'polygon-ecosystem-token',
#   'symbol': 'pol',
#   'name': 'POL (ex-MATIC)',
#   'current_price': 8.02,
#   'market_cap': 84894755520,
#   'market_cap_rank': 68,
#   'total_volume': 6167491081,
#   'circulating_supply': 10589625381.75776,
#   'total_supply': 10589625381.75776,
#   'ath': 106.68,
#   'atl': 7.85,
#   'last_updated': '2026-02-11T07:03:27.619Z'},
#  {'id': 'myx-finance',
#   'symbol': 'myx',
#   'name': 'MYX Finance',
#   'current_price': 444.65,
#   'market_cap': 84859038525,
#   'market_cap_rank': 69,
#   'total_volume': 1936634067,
#   'circulating_supply': 190768939.69,
#   'total_supply': 1000000000.0,
#   'ath': 1677.44,
#   'atl': 4.08,
#   'last_updated': '2026-02-11T07:03:27.366Z'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'current_price': 170.6,
#   'market_cap': 84019999069,
#   'market_cap_rank': 70,
#   'total_volume': 3072407711,
#   'circulating_supply': 492684848.339554,
#   'total_supply': 492684848.339554,
#   'ath': 3301.61,
#   'atl': 87.61,
#   'last_updated': '2026-02-11T07:03:27.570Z'},
#  {'id': 'ethena',
#   'symbol': 'ena',
#   'name': 'Ethena',
#   'current_price': 10.09,
#   'market_cap': 82965737979,
#   'market_cap_rank': 71,
#   'total_volume': 6609927378,
#   'circulating_supply': 8225000000.0,
#   'total_supply': 15000000000.0,
#   'ath': 126.48,
#   'atl': 9.4,
#   'last_updated': '2026-02-11T07:03:27.614Z'},
#  {'id': 'usdtb',
#   'symbol': 'usdtb',
#   'name': 'USDtb',
#   'current_price': 90.44,
#   'market_cap': 77273229473,
#   'market_cap_rank': 72,
#   'total_volume': 707590501,
#   'circulating_supply': 854399750.0161825,
#   'total_supply': 854399750.0161825,
#   'ath': 95.66,
#   'atl': 77.41,
#   'last_updated': '2026-02-11T07:03:27.013Z'},
#  {'id': 'kaspa',
#   'symbol': 'kas',
#   'name': 'Kaspa',
#   'current_price': 2.79,
#   'market_cap': 74568602687,
#   'market_cap_rank': 73,
#   'total_volume': 1417786886,
#   'circulating_supply': 26777148610.50726,
#   'total_supply': 27193324199.74955,
#   'ath': 17.36,
#   'atl': 0.01327337,
#   'last_updated': '2026-02-11T07:03:27.741Z'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'current_price': 4.38,
#   'market_cap': 72741993351,
#   'market_cap_rank': 74,
#   'total_volume': 801959764,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'ath': 10.66,
#   'atl': 2.14,
#   'last_updated': '2026-02-11T07:03:26.918Z'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'current_price': 72.4,
#   'market_cap': 72383006849,
#   'market_cap_rank': 75,
#   'total_volume': 1132854329,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 298.99,
#   'atl': 3.25,
#   'last_updated': '2026-02-11T07:03:27.038Z'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'current_price': 8.09,
#   'market_cap': 71769697690,
#   'market_cap_rank': 76,
#   'total_volume': 2885550018,
#   'circulating_supply': 8870434813.738161,
#   'total_supply': 8870726654.183462,
#   'ath': 247.29,
#   'atl': 7.26,
#   'last_updated': '2026-02-11T07:03:27.903Z'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'current_price': 0.839971,
#   'market_cap': 71171345594,
#   'market_cap_rank': 77,
#   'total_volume': 348629045,
#   'circulating_supply': 84702357423.53589,
#   'total_supply': 104903482401.2741,
#   'ath': 12.35,
#   'atl': 0.687929,
#   'last_updated': '2026-02-11T07:03:27.350Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'current_price': 87.63,
#   'market_cap': 67200459035,
#   'market_cap_rank': 78,
#   'total_volume': 5870405422,
#   'circulating_supply': 766870302.2938007,
#   'total_supply': 1195779117.621669,
#   'ath': 1622.34,
#   'atl': 84.41,
#   'last_updated': '2026-02-11T07:03:27.160Z'},
#  {'id': 'janus-henderson-anemoy-aaa-clo-fund',
#   'symbol': 'jaaa',
#   'name': 'Janus Henderson Anemoy AAA CLO Fund',
#   'current_price': 92.92,
#   'market_cap': 65975779192,
#   'market_cap_rank': 79,
#   'total_volume': None,
#   'circulating_supply': 710021691.915383,
#   'total_supply': 710021691.915383,
#   'ath': 94.38,
#   'atl': 89.64,
#   'last_updated': '2026-02-11T06:45:08.061Z'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'current_price': 283.13,
#   'market_cap': 65839133163,
#   'market_cap_rank': 80,
#   'total_volume': 6839841939,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'ath': 6357.94,
#   'atl': 283.52,
#   'last_updated': '2026-02-11T07:03:27.397Z'},
#  {'id': 'eutbl',
#   'symbol': 'eutbl',
#   'name': 'Spiko EU T-Bills Money Market Fund',
#   'current_price': 112.93,
#   'market_cap': 64827870386,
#   'market_cap_rank': 81,
#   'total_volume': None,
#   'circulating_supply': 574034711.71872,
#   'total_supply': 574034711.71872,
#   'ath': 115.38,
#   'atl': 84.72,
#   'last_updated': '2026-02-11T06:55:06.885Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'current_price': 3.19,
#   'market_cap': 63568877676,
#   'market_cap_rank': 83,
#   'total_volume': 1550931709,
#   'circulating_supply': 19931686474.62,
#   'total_supply': 38050680534.9,
#   'ath': 14.32,
#   'atl': 0.02721364,
#   'last_updated': '2026-02-11T07:03:27.429Z'},
#  {'id': 'ousg',
#   'symbol': 'ousg',
#   'name': 'OUSG',
#   'current_price': 10346.04,
#   'market_cap': 63486504408,
#   'market_cap_rank': 82,
#   'total_volume': 0.0,
#   'circulating_supply': 6135549.864477077,
#   'total_supply': 6135549.864477077,
#   'ath': 10520.12,
#   'atl': 7844.42,
#   'last_updated': '2026-02-11T07:00:09.784Z'},
#  {'id': 'ondo-us-dollar-yield',
#   'symbol': 'usdy',
#   'name': 'Ondo US Dollar Yield',
#   'current_price': 100.24,
#   'market_cap': 63079738505,
#   'market_cap_rank': 84,
#   'total_volume': 8770087,
#   'circulating_supply': 629239542.3596164,
#   'total_supply': 1164752243.712908,
#   'ath': 105.8,
#   'atl': 77.42,
#   'last_updated': '2026-02-11T07:03:26.960Z'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'current_price': 78.73,
#   'market_cap': 59217374266,
#   'market_cap_rank': 85,
#   'total_volume': 6834704527,
#   'circulating_supply': 752222335.0,
#   'total_supply': 1958290167.0,
#   'ath': 17367.85,
#   'atl': 73.41,
#   'last_updated': '2026-02-11T07:03:27.612Z'},
#  {'id': 'render-token',
#   'symbol': 'render',
#   'name': 'Render',
#   'current_price': 114.17,
#   'market_cap': 59215447636,
#   'market_cap_rank': 86,
#   'total_volume': 3814775904,
#   'circulating_supply': 518714713.0140741,
#   'total_supply': 533474886.2940741,
#   'ath': 1121.89,
#   'atl': 2.79,
#   'last_updated': '2026-02-11T07:03:27.628Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'current_price': 0.674067,
#   'market_cap': 57965989859,
#   'market_cap_rank': 87,
#   'total_volume': 1337453688,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'ath': 20.95,
#   'atl': 0.144791,
#   'last_updated': '2026-02-11T07:03:27.244Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'current_price': 9.69,
#   'market_cap': 56462392874,
#   'market_cap_rank': 88,
#   'total_volume': 6447193226,
#   'circulating_supply': 5826785045.0,
#   'total_supply': 10000000000.0,
#   'ath': 198.19,
#   'atl': 8.93,
#   'last_updated': '2026-02-11T07:03:27.364Z'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'current_price': 7.25,
#   'market_cap': 55150905631,
#   'market_cap_rank': 89,
#   'total_volume': 1125834733,
#   'circulating_supply': 7605571079.83814,
#   'total_supply': 9935871511.40607,
#   'ath': 32.42,
#   'atl': 0.01949843,
#   'last_updated': '2026-02-11T07:03:27.067Z'},
#  {'id': 'morpho',
#   'symbol': 'morpho',
#   'name': 'Morpho',
#   'current_price': 98.59,
#   'market_cap': 53803849300,
#   'market_cap_rank': 90,
#   'total_volume': 1189668718,
#   'circulating_supply': 546185996.7463505,
#   'total_supply': 1000000000.0,
#   'ath': 361.23,
#   'atl': 60.2,
#   'last_updated': '2026-02-11T07:03:27.143Z'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'current_price': 90.61,
#   'market_cap': 51890495420,
#   'market_cap_rank': 91,
#   'total_volume': 270746644,
#   'circulating_supply': 572709420.012226,
#   'total_supply': 572709420.012226,
#   'ath': 110.74,
#   'atl': 81.88,
#   'last_updated': '2026-02-11T07:03:26.973Z'},
#  {'id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'current_price': 99.07,
#   'market_cap': 51355470397,
#   'market_cap_rank': 92,
#   'total_volume': None,
#   'circulating_supply': 518328892.305495,
#   'total_supply': 518328892.305495,
#   'ath': 100.75,
#   'atl': 95.98,
#   'last_updated': '2026-02-11T07:00:08.563Z'},
#  {'id': 'usdai',
#   'symbol': 'usdai',
#   'name': 'USDai',
#   'current_price': 90.55,
#   'market_cap': 50010622966,
#   'market_cap_rank': 93,
#   'total_volume': 302178910,
#   'circulating_supply': 552278469.1877054,
#   'total_supply': 552278469.1877054,
#   'ath': 104.92,
#   'atl': 68.25,
#   'last_updated': '2026-02-11T07:03:27.101Z'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'current_price': 90.62,
#   'market_cap': 47788664894,
#   'market_cap_rank': 94,
#   'total_volume': 1583469052,
#   'circulating_supply': 527437881.2934199,
#   'total_supply': 527437881.2934199,
#   'ath': 92.12,
#   'atl': 76.18,
#   'last_updated': '2026-02-11T07:03:27.206Z'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'current_price': 0.00052279,
#   'market_cap': 46041384384,
#   'market_cap_rank': 95,
#   'total_volume': 4382381435,
#   'circulating_supply': 87995156319723.6,
#   'total_supply': 87995156319723.61,
#   'ath': 0.00491619,
#   'atl': 7.14e-06,
#   'last_updated': '2026-02-11T07:03:27.502Z'},
#  {'id': 'a7a5',
#   'symbol': 'a7a5',
#   'name': 'A7A5',
#   'current_price': 1.16,
#   'market_cap': 45421339834,
#   'market_cap_rank': 96,
#   'total_volume': 228173,
#   'circulating_supply': 39189098366.91073,
#   'total_supply': 39189098366.91073,
#   'ath': 20.14,
#   'atl': 0.00091492,
#   'last_updated': '2026-02-11T07:03:27.027Z'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'current_price': 90.39,
#   'market_cap': 44695778720,
#   'market_cap_rank': 97,
#   'total_volume': 702941676,
#   'circulating_supply': 494515083.0,
#   'total_supply': 494515083.0,
#   'ath': 112.93,
#   'atl': 64.32,
#   'last_updated': '2026-02-11T07:03:27.758Z'},
#  {'id': 'fasttoken',
#   'symbol': 'ftn',
#   'name': 'Fasttoken',
#   'current_price': 98.56,
#   'market_cap': 42756668654,
#   'market_cap_rank': 98,
#   'total_volume': 999810061,
#   'circulating_supply': 433857414.6,
#   'total_supply': 870742437.0,
#   'ath': 403.42,
#   'atl': 30.21,
#   'last_updated': '2026-02-11T07:03:27.156Z'},
#  {'id': 'layerzero',
#   'symbol': 'zro',
#   'name': 'LayerZero',
#   'current_price': 210.9,
#   'market_cap': 42341414495,
#   'market_cap_rank': 99,
#   'total_volume': 53093743186,
#   'circulating_supply': 202629028.12286997,
#   'total_supply': 1000000000.0,
#   'ath': 632.92,
#   'atl': 99.55,
#   'last_updated': '2026-02-11T07:03:27.600Z'},
#  {'id': 'sei-network',
#   'symbol': 'sei',
#   'name': 'Sei',
#   'current_price': 6.38,
#   'market_cap': 42168291487,
#   'market_cap_rank': 100,
#   'total_volume': 3259677577,
#   'circulating_supply': 6612222222.0,
#   'total_supply': 10000000000.0,
#   'ath': 94.47,
#   'atl': 6.23,
#   'last_updated': '2026-02-11T07:03:27.593Z'},
#  {'id': 'euro-coin',
#   'symbol': 'eurc',
#   'name': 'EURC',
#   'current_price': 107.89,
#   'market_cap': 41534805889,
#   'market_cap_rank': 101,
#   'total_volume': 2696479335,
#   'circulating_supply': 384745633.6855321,
#   'total_supply': 384193942.0675721,
#   'ath': 111.47,
#   'atl': 4.35,
#   'last_updated': '2026-02-11T07:03:27.173Z'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'current_price': 12.59,
#   'market_cap': 40844246025,
#   'market_cap_rank': 102,
#   'total_volume': 2296458072,
#   'circulating_supply': 3243891294.88,
#   'total_supply': 6863982888.464856,
#   'ath': 166.05,
#   'atl': 12.59,
#   'last_updated': '2026-02-11T07:03:27.630Z'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'current_price': 22.17,
#   'market_cap': 39383617124,
#   'market_cap_rank': 103,
#   'total_volume': 1089831089,
#   'circulating_supply': 1776346416.13918,
#   'total_supply': 1776346416.13918,
#   'ath': 322.23,
#   'atl': 3.44,
#   'last_updated': '2026-02-11T07:03:27.750Z'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'current_price': 3068.67,
#   'market_cap': 38622962580,
#   'market_cap_rank': 104,
#   'total_volume': 4991478964,
#   'circulating_supply': 12583429.59098425,
#   'total_supply': 12585035.83681419,
#   'ath': 95552,
#   'atl': 13.82,
#   'last_updated': '2026-02-11T07:03:27.367Z'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'current_price': 116.18,
#   'market_cap': 38580246313,
#   'market_cap_rank': 105,
#   'total_volume': 2430070062,
#   'circulating_supply': 332119024.1191414,
#   'total_supply': 345453343.4723421,
#   'ath': 3259.75,
#   'atl': 14.48,
#   'last_updated': '2026-02-11T07:03:27.597Z'},
#  {'id': 'pippin',
#   'symbol': 'pippin',
#   'name': 'pippin',
#   'current_price': 37.97,
#   'market_cap': 38022013736,
#   'market_cap_rank': 106,
#   'total_volume': 4781184832,
#   'circulating_supply': 999937507.202199,
#   'total_supply': 999937507.202199,
#   'ath': 50.39,
#   'atl': 0.473545,
#   'last_updated': '2026-02-11T07:03:27.497Z'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'current_price': 35.05,
#   'market_cap': 37679312230,
#   'market_cap_rank': 107,
#   'total_volume': 1512850944,
#   'circulating_supply': 1075063402.570743,
#   'total_supply': 1095123638.582185,
#   'ath': 676.89,
#   'atl': 24.73,
#   'last_updated': '2026-02-11T07:03:27.722Z'},
#  {'id': 'first-digital-usd',
#   'symbol': 'fdusd',
#   'name': 'First Digital USD',
#   'current_price': 90.44,
#   'market_cap': 35973128039,
#   'market_cap_rank': 109,
#   'total_volume': 5346643755,
#   'circulating_supply': 397715236.2794249,
#   'total_supply': 397715236.2794249,
#   'ath': 100.07,
#   'atl': 78.29,
#   'last_updated': '2026-02-11T07:03:27.601Z'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'current_price': 3.5,
#   'market_cap': 35947199097,
#   'market_cap_rank': 108,
#   'total_volume': 4769262361,
#   'circulating_supply': 10269209250.0,
#   'total_supply': 10269209250.0,
#   'ath': 63.87,
#   'atl': 0.290329,
#   'last_updated': '2026-02-11T07:03:27.239Z'},
#  {'id': 'decred',
#   'symbol': 'dcr',
#   'name': 'Decred',
#   'current_price': 2064.52,
#   'market_cap': 35659522831,
#   'market_cap_rank': 110,
#   'total_volume': 587238181,
#   'circulating_supply': 17269150.33333832,
#   'total_supply': 17269645.396715,
#   'ath': 18443.33,
#   'atl': 29.25,
#   'last_updated': '2026-02-11T07:03:27.737Z'},
#  {'id': 'story-2',
#   'symbol': 'ip',
#   'name': 'Story',
#   'current_price': 101.34,
#   'market_cap': 35332574014,
#   'market_cap_rank': 111,
#   'total_volume': 5043340904,
#   'circulating_supply': 350245630.93,
#   'total_supply': 1023765723.6,
#   'ath': 1302.35,
#   'atl': 87.81,
#   'last_updated': '2026-02-11T07:03:27.569Z'},
#  {'id': 'kinesis-gold',
#   'symbol': 'kau',
#   'name': 'Kinesis Gold',
#   'current_price': 14671.67,
#   'market_cap': 35004961390,
#   'market_cap_rank': 112,
#   'total_volume': 10734930,
#   'circulating_supply': 2386227.8342,
#   'total_supply': 2386227.8342,
#   'ath': 16353.61,
#   'atl': 3614.27,
#   'last_updated': '2026-02-11T07:03:27.288Z'},
#  {'id': 'stable-2',
#   'symbol': 'stable',
#   'name': '\u200b\u200bStable',
#   'current_price': 1.9,
#   'market_cap': 34216394217,
#   'market_cap_rank': 113,
#   'total_volume': 4483234194,
#   'circulating_supply': 18000000000.0,
#   'total_supply': 100000000000.0,
#   'ath': 2.93,
#   'atl': 0.827533,
#   'last_updated': '2026-02-11T07:03:27.130Z'},
#  {'id': 'optimism',
#   'symbol': 'op',
#   'name': 'Optimism',
#   'current_price': 16.0,
#   'market_cap': 33855807961,
#   'market_cap_rank': 114,
#   'total_volume': 3893696524,
#   'circulating_supply': 2116007431.0,
#   'total_supply': 4294967296.0,
#   'ath': 401.58,
#   'atl': 14.88,
#   'last_updated': '2026-02-11T07:03:28.001Z'},
#  {'id': 'pudgy-penguins',
#   'symbol': 'pengu',
#   'name': 'Pudgy Penguins',
#   'current_price': 0.537008,
#   'market_cap': 33762451114,
#   'market_cap_rank': 115,
#   'total_volume': 5594586329,
#   'circulating_supply': 62860396090.0,
#   'total_supply': 79734268697.85313,
#   'ath': 5.81,
#   'atl': 0.320882,
#   'last_updated': '2026-02-11T07:03:27.620Z'},
#  {'id': 'river',
#   'symbol': 'river',
#   'name': 'River',
#   'current_price': 1715.34,
#   'market_cap': 33547234577,
#   'market_cap_rank': 116,
#   'total_volume': 7553535768,
#   'circulating_supply': 19600000.0,
#   'total_supply': 100000000.0,
#   'ath': 8042.31,
#   'atl': 140.15,
#   'last_updated': '2026-02-11T07:03:27.325Z'},
#  {'id': 'virtual-protocol',
#   'symbol': 'virtual',
#   'name': 'Virtuals Protocol',
#   'current_price': 49.49,
#   'market_cap': 32475575769,
#   'market_cap_rank': 117,
#   'total_volume': 4463094830,
#   'circulating_supply': 656282621.3333926,
#   'total_supply': 1000000000.0,
#   'ath': 434.45,
#   'atl': 0.622571,
#   'last_updated': '2026-02-11T07:03:27.714Z'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'current_price': 3.67,
#   'market_cap': 32351512407,
#   'market_cap_rank': 118,
#   'total_volume': 1806615484,
#   'circulating_supply': 8815108920.581306,
#   'total_supply': 8815108920.581306,
#   'ath': 14.19,
#   'atl': 0.359754,
#   'last_updated': '2026-02-11T07:03:27.430Z'},
#  {'id': 'c8ntinuum',
#   'symbol': 'ctm',
#   'name': 'c8ntinuum',
#   'current_price': 7.34,
#   'market_cap': 31980644088,
#   'market_cap_rank': 119,
#   'total_volume': 98792985,
#   'circulating_supply': 4359542107.432732,
#   'total_supply': 8888888888.0,
#   'ath': 13.05,
#   'atl': 0.709073,
#   'last_updated': '2026-02-11T07:03:27.125Z'},
#  {'id': 'lighter',
#   'symbol': 'lit',
#   'name': 'Lighter',
#   'current_price': 126.92,
#   'market_cap': 31740203470,
#   'market_cap_rank': 120,
#   'total_volume': 2342728286,
#   'circulating_supply': 250000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 705.52,
#   'atl': 123.01,
#   'last_updated': '2026-02-11T07:03:27.295Z'},
#  {'id': 'fetch-ai',
#   'symbol': 'fet',
#   'name': 'Artificial Superintelligence Alliance',
#   'current_price': 13.78,
#   'market_cap': 31450123301,
#   'market_cap_rank': 121,
#   'total_volume': 3444532764,
#   'circulating_supply': 2282861718.9251046,
#   'total_supply': 2714384546.672,
#   'ath': 287.87,
#   'atl': 0.616804,
#   'last_updated': '2026-02-11T07:03:27.575Z'},
#  {'id': 'curve-dao-token',
#   'symbol': 'crv',
#   'name': 'Curve DAO',
#   'current_price': 20.58,
#   'market_cap': 30356971534,
#   'market_cap_rank': 122,
#   'total_volume': 7092435810,
#   'circulating_supply': 1475304763.0,
#   'total_supply': 2351307576.498001,
#   'ath': 1150.14,
#   'atl': 15.17,
#   'last_updated': '2026-02-11T07:03:27.655Z'},
#  {'id': 'bittorrent',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'current_price': 3.022e-05,
#   'market_cap': 29871390166,
#   'market_cap_rank': 124,
#   'total_volume': 1140234613,
#   'circulating_supply': 987037885840674.8,
#   'total_supply': 990000000000000.0,
#   'ath': 0.00025579,
#   'atl': 2.748e-05,
#   'last_updated': '2026-02-11T07:03:27.352Z'},
#  {'id': 'kite-2',
#   'symbol': 'kite',
#   'name': 'Kite',
#   'current_price': 16.5,
#   'market_cap': 29832711031,
#   'market_cap_rank': 123,
#   'total_volume': 5250155712,
#   'circulating_supply': 1800000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 17.82,
#   'atl': 5.48,
#   'last_updated': '2026-02-11T07:03:27.251Z'},
#  {'id': 'gnosis',
#   'symbol': 'gno',
#   'name': 'Gnosis',
#   'current_price': 11051.84,
#   'market_cap': 29178949888,
#   'market_cap_rank': 125,
#   'total_volume': 464762817,
#   'circulating_supply': 2639589.0,
#   'total_supply': 3000000.0,
#   'ath': 47603,
#   'atl': 519.75,
#   'last_updated': '2026-02-11T07:03:27.701Z'},
#  {'id': 'sun-token',
#   'symbol': 'sun',
#   'name': 'Sun Token',
#   'current_price': 1.5,
#   'market_cap': 28855508262,
#   'market_cap_rank': 126,
#   'total_volume': 3067874307,
#   'circulating_supply': 19208721222.33119,
#   'total_supply': 19900730000.0,
#   'ath': 4880.96,
#   'atl': 0.374246,
#   'last_updated': '2026-02-11T07:03:27.268Z'},
#  {'id': 'resolv-usr',
#   'symbol': 'usr',
#   'name': 'Resolv USR',
#   'current_price': 90.5,
#   'market_cap': 28681301940,
#   'market_cap_rank': 127,
#   'total_volume': 11706417,
#   'circulating_supply': 316920812.7840972,
#   'total_supply': 316920812.7840972,
#   'ath': 92.16,
#   'atl': 82.39,
#   'last_updated': '2026-02-11T07:03:27.493Z'},
#  {'id': 'syrup',
#   'symbol': 'syrup',
#   'name': 'Maple Finance',
#   'current_price': 24.29,
#   'market_cap': 28125169565,
#   'market_cap_rank': 128,
#   'total_volume': 652962978,
#   'circulating_supply': 1157190702.5885315,
#   'total_supply': 1216127147.998563,
#   'ath': 56.23,
#   'atl': 7.31,
#   'last_updated': '2026-02-11T07:03:27.498Z'},
#  {'id': 'kaia',
#   'symbol': 'kaia',
#   'name': 'Kaia',
#   'current_price': 4.79,
#   'market_cap': 28049499070,
#   'market_cap_rank': 129,
#   'total_volume': 704594501,
#   'circulating_supply': 5856641747.106198,
#   'total_supply': 5856641936.044253,
#   'ath': 34.46,
#   'atl': 4.23,
#   'last_updated': '2026-02-11T07:03:27.788Z'},
#  {'id': 'apenft',
#   'symbol': 'nft',
#   'name': 'AINFT',
#   'current_price': 2.828e-05,
#   'market_cap': 27987314674,
#   'market_cap_rank': 130,
#   'total_volume': 1239727687,
#   'circulating_supply': 990105667256391.5,
#   'total_supply': 990105667256391.5,
#   'ath': 0.00054965,
#   'atl': 2.463e-05,
#   'last_updated': '2026-02-11T07:03:27.247Z'},
#  {'id': 'kinesis-silver',
#   'symbol': 'kag',
#   'name': 'Kinesis Silver',
#   'current_price': 7420.2,
#   'market_cap': 27608371238,
#   'market_cap_rank': 131,
#   'total_volume': 50070007,
#   'circulating_supply': 3721963.8196,
#   'total_supply': 3721963.8196,
#   'ath': 11907.44,
#   'atl': 362.2,
#   'last_updated': '2026-02-11T07:03:27.546Z'},
#  {'id': 'ether-fi',
#   'symbol': 'ethfi',
#   'name': 'Ether.fi',
#   'current_price': 38.71,
#   'market_cap': 27043248388,
#   'market_cap_rank': 132,
#   'total_volume': 2874147642,
#   'circulating_supply': 699363510.0,
#   'total_supply': 998535999.0,
#   'ath': 711.06,
#   'atl': 34.7,
#   'last_updated': '2026-02-11T07:03:27.332Z'},
#  {'id': 'injective-protocol',
#   'symbol': 'inj',
#   'name': 'Injective',
#   'current_price': 269.0,
#   'market_cap': 26900009828,
#   'market_cap_rank': 133,
#   'total_volume': 3021172476,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'ath': 4364.19,
#   'atl': 49.02,
#   'last_updated': '2026-02-11T07:03:28.079Z'},
#  {'id': 'usx',
#   'symbol': 'usx',
#   'name': 'USX',
#   'current_price': 90.52,
#   'market_cap': 26600125969,
#   'market_cap_rank': 134,
#   'total_volume': 858457058,
#   'circulating_supply': 293923154.85157,
#   'total_supply': 293923154.85157,
#   'ath': 95.56,
#   'atl': 74.4,
#   'last_updated': '2026-02-11T07:03:27.341Z'},
#  {'id': 'crvusd',
#   'symbol': 'crvusd',
#   'name': 'crvUSD',
#   'current_price': 90.33,
#   'market_cap': 26466763503,
#   'market_cap_rank': 135,
#   'total_volume': 3480557034,
#   'circulating_supply': 293132433.6345274,
#   'total_supply': 293132433.6345274,
#   'ath': 96.91,
#   'atl': 78.57,
#   'last_updated': '2026-02-11T07:03:28.025Z'},
#  {'id': 'hastra-prime',
#   'symbol': 'prime',
#   'name': 'PRIME',
#   'current_price': 92.2,
#   'market_cap': 25818963297,
#   'market_cap_rank': 136,
#   'total_volume': 772233439,
#   'circulating_supply': 280044316.38391,
#   'total_supply': 280044316.38391,
#   'ath': 94.01,
#   'atl': 89.31,
#   'last_updated': '2026-02-11T07:03:27.395Z'},
#  {'id': 'iota',
#   'symbol': 'iota',
#   'name': 'IOTA',
#   'current_price': 5.93,
#   'market_cap': 25385923832,
#   'market_cap_rank': 137,
#   'total_volume': 582244829,
#   'circulating_supply': 4283522973.0,
#   'total_supply': 4815450646.0,
#   'ath': 336.22,
#   'atl': 5.75,
#   'last_updated': '2026-02-11T07:03:27.394Z'},
#  {'id': 'floki',
#   'symbol': 'floki',
#   'name': 'FLOKI',
#   'current_price': 0.00260697,
#   'market_cap': 25167921760,
#   'market_cap_rank': 138,
#   'total_volume': 2512614776,
#   'circulating_supply': 9655017300149.0,
#   'total_supply': 10000000000000.0,
#   'ath': 0.02877055,
#   'atl': 6.26e-06,
#   'last_updated': '2026-02-11T07:03:27.697Z'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'current_price': 29.57,
#   'market_cap': 25080540934,
#   'market_cap_rank': 139,
#   'total_volume': 2091972322,
#   'circulating_supply': 848066802.5927889,
#   'total_supply': 1000000000.0,
#   'ath': 543.56,
#   'atl': 26.78,
#   'last_updated': '2026-02-11T07:03:28.024Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'current_price': 2.33,
#   'market_cap': 24916408038,
#   'market_cap_rank': 140,
#   'total_volume': 1059128278,
#   'circulating_supply': 10707315864.54818,
#   'total_supply': 10800262816.04821,
#   'ath': 206.81,
#   'atl': 2.12,
#   'last_updated': '2026-02-11T07:03:27.918Z'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Legacy Frax Dollar',
#   'current_price': 89.95,
#   'market_cap': 24826278632,
#   'market_cap_rank': 141,
#   'total_volume': 522584649,
#   'circulating_supply': 276015184.0102677,
#   'total_supply': 276015184.0102677,
#   'ath': 91.66,
#   'atl': 67.16,
#   'last_updated': '2026-02-11T07:03:27.621Z'},
#  {'id': 'humanity',
#   'symbol': 'h',
#   'name': 'Humanity',
#   'current_price': 13.54,
#   'market_cap': 24737758395,
#   'market_cap_rank': 142,
#   'total_volume': 1545212824,
#   'circulating_supply': 1825000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 34.11,
#   'atl': 1.55,
#   'last_updated': '2026-02-11T07:03:27.528Z'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'current_price': 1234.06,
#   'market_cap': 24672531509,
#   'market_cap_rank': 143,
#   'total_volume': 351757521,
#   'circulating_supply': 19986881.25,
#   'total_supply': 19986918.75,
#   'ath': 36495,
#   'atl': 1043.89,
#   'last_updated': '2026-02-11T07:03:28.253Z'},
#  {'id': 'celestia',
#   'symbol': 'tia',
#   'name': 'Celestia',
#   'current_price': 27.68,
#   'market_cap': 24321830527,
#   'market_cap_rank': 144,
#   'total_volume': 1995522224,
#   'circulating_supply': 878520222.358706,
#   'total_supply': 1161386648.78766,
#   'ath': 1730.96,
#   'atl': 25.29,
#   'last_updated': '2026-02-11T07:03:27.386Z'},
#  {'id': 'olympus',
#   'symbol': 'ohm',
#   'name': 'Olympus',
# ...
#   'last_updated': '2026-02-11T07:03:30.028Z'},
#  {'id': 'marsmi',
#   'symbol': 'marsmi',
#   'name': 'MarsMi',
#   'current_price': 2.24,
#   'market_cap': 2238509660,
#   'market_cap_rank': 702,
#   'total_volume': 13446841,
#   'circulating_supply': 999999978.227557,
#   'total_supply': 999999978.227557,
#   'ath': 16.22,
#   'atl': 2.04,
#   'last_updated': '2026-02-11T07:03:29.955Z'},
#  {'id': 'momentum-3',
#   'symbol': 'mmt',
#   'name': 'Momentum',
#   'current_price': 10.96,
#   'market_cap': 2235913910,
#   'market_cap_rank': 703,
#   'total_volume': 599581884,
#   'circulating_supply': 204095424.0,
#   'total_supply': 1000000000.0,
#   'ath': 357.49,
#   'atl': 10.51,
#   'last_updated': '2026-02-11T07:03:30.090Z'},
#  {'id': 'kyber-network-crystal',
#   'symbol': 'knc',
#   'name': 'Kyber Network Crystal',
#   'current_price': 13.13,
#   'market_cap': 2232607886,
#   'market_cap_rank': 705,
#   'total_volume': 816251912,
#   'circulating_supply': 170152851.23024455,
#   'total_supply': 240893671.044645,
#   'ath': 436.19,
#   'atl': 12.59,
#   'last_updated': '2026-02-11T07:03:30.049Z'},
#  {'id': 'superwalk',
#   'symbol': 'grnd',
#   'name': 'SuperWalk GRND',
#   'current_price': 3.15,
#   'market_cap': 2230276855,
#   'market_cap_rank': 706,
#   'total_volume': 6241984,
#   'circulating_supply': 707660423.05,
#   'total_supply': 987522926.0,
#   'ath': 31.92,
#   'atl': 1.96,
#   'last_updated': '2026-02-11T07:03:30.037Z'},
#  {'id': 'the-grays-currency',
#   'symbol': 'ptgc',
#   'name': 'The Grays Currency',
#   'current_price': 0.00764151,
#   'market_cap': 2213014966,
#   'market_cap_rank': 707,
#   'total_volume': 2406567,
#   'circulating_supply': 289877801586.086,
#   'total_supply': 289877801586.086,
#   'ath': 0.115141,
#   'atl': 0.00018075,
#   'last_updated': '2026-02-11T07:03:29.989Z'},
#  {'id': 'acurast',
#   'symbol': 'acu',
#   'name': 'Acurast',
#   'current_price': 9.89,
#   'market_cap': 2204130303,
#   'market_cap_rank': 709,
#   'total_volume': 494492279,
#   'circulating_supply': 222744599.8,
#   'total_supply': 1002846362.72,
#   'ath': 28.94,
#   'atl': 6.34,
#   'last_updated': '2026-02-11T07:03:30.032Z'},
#  {'id': 'across-protocol',
#   'symbol': 'acx',
#   'name': 'Across Protocol',
#   'current_price': 3.21,
#   'market_cap': 2203118920,
#   'market_cap_rank': 708,
#   'total_volume': 125841054,
#   'circulating_supply': 686606397.0593098,
#   'total_supply': 1000000000.0,
#   'ath': 143.0,
#   'atl': 2.84,
#   'last_updated': '2026-02-11T07:03:30.071Z'},
#  {'id': 'micron-technology-ondo-tokenized-stock',
#   'symbol': 'muon',
#   'name': 'Micron Technology (Ondo Tokenized Stock)',
#   'current_price': 33866,
#   'market_cap': 2203024813,
#   'market_cap_rank': 710,
#   'total_volume': 393729629,
#   'circulating_supply': 65050.32498463058,
#   'total_supply': 65050.32498463058,
#   'ath': 41937,
#   'atl': 10205.02,
#   'last_updated': '2026-02-11T07:03:30.041Z'},
#  {'id': 'sharp-token',
#   'symbol': 'sharp',
#   'name': 'Sharp Token',
#   'current_price': 0.651958,
#   'market_cap': 2200414812,
#   'market_cap_rank': 711,
#   'total_volume': 3511175,
#   'circulating_supply': 3376492186.6666665,
#   'total_supply': 68230000000.0,
#   'ath': 1.056,
#   'atl': 0.289404,
#   'last_updated': '2026-02-11T07:03:30.111Z'},
#  {'id': 'electronic-usd',
#   'symbol': 'eusd',
#   'name': 'Electronic USD',
#   'current_price': 90.44,
#   'market_cap': 2191588084,
#   'market_cap_rank': 712,
#   'total_volume': 47691848,
#   'circulating_supply': 24232437.8884462,
#   'total_supply': 24232437.8884462,
#   'ath': 94.57,
#   'atl': 71.88,
#   'last_updated': '2026-02-11T07:03:30.081Z'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi',
#   'current_price': 19.85,
#   'market_cap': 2183686878,
#   'market_cap_rank': 713,
#   'total_volume': 13083676,
#   'circulating_supply': 109395689.2524321,
#   'total_supply': 109395689.2524321,
#   'ath': 2918.58,
#   'atl': 12.64,
#   'last_updated': '2026-02-11T07:03:29.946Z'},
#  {'id': 'gyroscope-gyd',
#   'symbol': 'gyd',
#   'name': 'Gyroscope GYD',
#   'current_price': 90.99,
#   'market_cap': 2202811214,
#   'market_cap_rank': 714,
#   'total_volume': 53.0,
#   'circulating_supply': 24208960.0029494,
#   'total_supply': 24208960.0029494,
#   'ath': 93.94,
#   'atl': 68.25,
#   'last_updated': '2026-02-01T07:23:58.923Z'},
#  {'id': 'medibloc',
#   'symbol': 'med',
#   'name': 'Medibloc',
#   'current_price': 0.203486,
#   'market_cap': 2173991741,
#   'market_cap_rank': 717,
#   'total_volume': 24713509,
#   'circulating_supply': 10644041819.0,
#   'total_supply': 11434259731.0,
#   'ath': 25.79,
#   'atl': 0.121837,
#   'last_updated': '2026-02-11T07:03:30.060Z'},
#  {'id': 'global-commercial-business',
#   'symbol': 'gcb',
#   'name': 'Global Commercial Business',
#   'current_price': 1.8,
#   'market_cap': 2167583670,
#   'market_cap_rank': 715,
#   'total_volume': 10865.67,
#   'circulating_supply': 1201844746.3739874,
#   'total_supply': 1201844746.3739874,
#   'ath': 28.6,
#   'atl': 1.75,
#   'last_updated': '2026-02-11T07:03:30.090Z'},
#  {'id': 'degen-base',
#   'symbol': 'degen',
#   'name': 'Degen',
#   'current_price': 0.058597,
#   'market_cap': 2164976619,
#   'market_cap_rank': 716,
#   'total_volume': 185859939,
#   'circulating_supply': 36965730333.0,
#   'total_supply': 36965730333.0,
#   'ath': 5.38,
#   'atl': 0.00186847,
#   'last_updated': '2026-02-11T07:03:30.142Z'},
#  {'id': 'cargox',
#   'symbol': 'cxo',
#   'name': 'CargoX',
#   'current_price': 12.94,
#   'market_cap': 2164020770,
#   'market_cap_rank': 718,
#   'total_volume': 2643734,
#   'circulating_supply': 167160147.72525844,
#   'total_supply': 215119016.0,
#   'ath': 43.58,
#   'atl': 0.00284545,
#   'last_updated': '2026-02-11T07:03:30.091Z'},
#  {'id': 'palladium-network',
#   'symbol': 'plld',
#   'name': 'Palladium Network',
#   'current_price': 41.83,
#   'market_cap': 2159942887,
#   'market_cap_rank': 719,
#   'total_volume': 8252713,
#   'circulating_supply': 51641522.04803534,
#   'total_supply': 52643000.0,
#   'ath': 527.08,
#   'atl': 19.89,
#   'last_updated': '2026-02-11T07:03:29.889Z'},
#  {'id': 'faith-tribe',
#   'symbol': 'ftrb',
#   'name': 'Faith Tribe',
#   'current_price': 0.662742,
#   'market_cap': 2140916380,
#   'market_cap_rank': 720,
#   'total_volume': 45981695,
#   'circulating_supply': 3229510514.05,
#   'total_supply': 5000000000.0,
#   'ath': 5.36,
#   'atl': 0.145084,
#   'last_updated': '2026-02-11T07:03:30.136Z'},
#  {'id': 'honey-3',
#   'symbol': 'honey',
#   'name': 'Honey',
#   'current_price': 90.37,
#   'market_cap': 2131043201,
#   'market_cap_rank': 721,
#   'total_volume': 143222548,
#   'circulating_supply': 23581280.43115645,
#   'total_supply': 23581280.43115645,
#   'ath': 137.3,
#   'atl': 80.3,
#   'last_updated': '2026-02-11T07:03:30.147Z'},
#  {'id': 'bitlayer-bitvm',
#   'symbol': 'btr',
#   'name': 'Bitlayer',
#   'current_price': 8.1,
#   'market_cap': 2120972400,
#   'market_cap_rank': 722,
#   'total_volume': 510165673,
#   'circulating_supply': 261600000.0,
#   'total_supply': 1000000000.0,
#   'ath': 15.22,
#   'atl': 2.13,
#   'last_updated': '2026-02-11T07:03:30.227Z'},
#  {'id': 'hippo-protocol',
#   'symbol': 'hp',
#   'name': 'Hippo Protocol',
#   'current_price': 1.64,
#   'market_cap': 2120139848,
#   'market_cap_rank': 723,
#   'total_volume': 32040158,
#   'circulating_supply': 1292020058.457474,
#   'total_supply': 1293172588.621877,
#   'ath': 5.83,
#   'atl': 1.52,
#   'last_updated': '2026-02-11T07:03:30.141Z'},
#  {'id': 'metal',
#   'symbol': 'mtl',
#   'name': 'Metal DAO',
#   'current_price': 23.77,
#   'market_cap': 2119280677,
#   'market_cap_rank': 724,
#   'total_volume': 93861108,
#   'circulating_supply': 89153205.0,
#   'total_supply': 89153205.0,
#   'ath': 1160.85,
#   'atl': 8.85,
#   'last_updated': '2026-02-11T07:03:30.105Z'},
#  {'id': 'sats-ordinals',
#   'symbol': 'sats',
#   'name': 'SATS (Ordinals)',
#   'current_price': 1e-06,
#   'market_cap': 2105395646,
#   'market_cap_rank': 725,
#   'total_volume': 228214526,
#   'circulating_supply': 2100000000000000.0,
#   'total_supply': 2100000000000000.0,
#   'ath': 7.675e-05,
#   'atl': 2.63579e-07,
#   'last_updated': '2026-02-11T07:03:30.128Z'},
#  {'id': 'cartesi',
#   'symbol': 'ctsi',
#   'name': 'Cartesi',
#   'current_price': 2.33,
#   'market_cap': 2104977230,
#   'market_cap_rank': 726,
#   'total_volume': 156239722,
#   'circulating_supply': 903782031.7900137,
#   'total_supply': 1000000000.0,
#   'ath': 127.9,
#   'atl': 2.01,
#   'last_updated': '2026-02-11T07:03:30.245Z'},
#  {'id': 'nietzschean-penguin',
#   'symbol': 'penguin',
#   'name': 'Nietzschean Penguin',
#   'current_price': 2.1,
#   'market_cap': 2102103265,
#   'market_cap_rank': 727,
#   'total_volume': 1887836573,
#   'circulating_supply': 999976125.058593,
#   'total_supply': 999976125.058593,
#   'ath': 14.7,
#   'atl': 0.454565,
#   'last_updated': '2026-02-11T07:03:30.340Z'},
#  {'id': 'planet-ix',
#   'symbol': 'aix',
#   'name': 'Planet IX',
#   'current_price': 11.57,
#   'market_cap': 2100309834,
#   'market_cap_rank': 728,
#   'total_volume': 9607726,
#   'circulating_supply': 181600000.0,
#   'total_supply': 306000000.0,
#   'ath': 40.83,
#   'atl': 10.04,
#   'last_updated': '2026-02-11T07:03:30.118Z'},
#  {'id': 'midas-mapollo',
#   'symbol': 'mapollo',
#   'name': 'Midas mAPOLLO',
#   'current_price': 96.9,
#   'market_cap': 2096466082,
#   'market_cap_rank': 729,
#   'total_volume': 96.08,
#   'circulating_supply': 21633333.36679924,
#   'total_supply': 21633333.36679924,
#   'ath': 98.58,
#   'atl': 89.62,
#   'last_updated': '2026-02-11T07:00:14.507Z'},
#  {'id': 'invesco-qqq-etf-ondo-tokenized-etf',
#   'symbol': 'qqqon',
#   'name': 'Invesco QQQ ETF (Ondo Tokenized ETF)',
#   'current_price': 55623,
#   'market_cap': 2095555339,
#   'market_cap_rank': 730,
#   'total_volume': 111315807,
#   'circulating_supply': 37674.18979278109,
#   'total_supply': 37674.18979278109,
#   'ath': 58660,
#   'atl': 49290,
#   'last_updated': '2026-02-11T07:03:30.172Z'},
#  {'id': 'usual',
#   'symbol': 'usual',
#   'name': 'Usual',
#   'current_price': 1.28,
#   'market_cap': 2092229520,
#   'market_cap_rank': 731,
#   'total_volume': 239984495,
#   'circulating_supply': 1638803828.4037025,
#   'total_supply': 1642722416.147725,
#   'ath': 137.03,
#   'atl': 0.931235,
#   'last_updated': '2026-02-11T07:03:30.162Z'},
#  {'id': 'pepenguin',
#   'symbol': 'penguin',
#   'name': 'PePenguin',
#   'current_price': 2.1,
#   'market_cap': 2090326962,
#   'market_cap_rank': 732,
#   'total_volume': 63081496,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 2.27,
#   'atl': 0.00014135,
#   'last_updated': '2026-02-11T07:03:30.311Z'},
#  {'id': 'aevo-exchange',
#   'symbol': 'aevo',
#   'name': 'Aevo',
#   'current_price': 2.28,
#   'market_cap': 2084505411,
#   'market_cap_rank': 733,
#   'total_volume': 457241691,
#   'circulating_supply': 916162381.6383989,
#   'total_supply': 1000000000.0,
#   'ath': 313.13,
#   'atl': 2.27,
#   'last_updated': '2026-02-11T07:03:30.187Z'},
#  {'id': 'ao-computer',
#   'symbol': 'ao',
#   'name': 'ao Computer',
#   'current_price': 345.47,
#   'market_cap': 2078291478,
#   'market_cap_rank': 735,
#   'total_volume': 8512330,
#   'circulating_supply': 6015800.0,
#   'total_supply': 6015800.0,
#   'ath': 4281.57,
#   'atl': 303.95,
#   'last_updated': '2026-02-11T07:03:30.205Z'},
#  {'id': 'autonomi',
#   'symbol': 'ant',
#   'name': 'Autonomi',
#   'current_price': 6.94,
#   'market_cap': 2077917396,
#   'market_cap_rank': 734,
#   'total_volume': 29590563,
#   'circulating_supply': 299605073.6725304,
#   'total_supply': 1200000000.0,
#   'ath': 28.84,
#   'atl': 0.253538,
#   'last_updated': '2026-02-11T07:03:30.201Z'},
#  {'id': 'circle-xstock',
#   'symbol': 'crclx',
#   'name': 'Circle xStock',
#   'current_price': 5251.09,
#   'market_cap': 2075169249,
#   'market_cap_rank': 736,
#   'total_volume': 1720156609,
#   'circulating_supply': 395353.7217778788,
#   'total_supply': 2124985.48356901,
#   'ath': 22140,
#   'atl': 4337.07,
#   'last_updated': '2026-02-11T07:03:30.166Z'},
#  {'id': 'pinksale',
#   'symbol': 'pinksale',
#   'name': 'PinkSale',
#   'current_price': 20740,
#   'market_cap': 2073962495,
#   'market_cap_rank': 738,
#   'total_volume': 660.79,
#   'circulating_supply': 100000.0,
#   'total_supply': 100000.0,
#   'ath': 44812,
#   'atl': 3523.92,
#   'last_updated': '2026-02-10T09:33:52.786Z'},
#  {'id': 'chromaway',
#   'symbol': 'chr',
#   'name': 'Chromia',
#   'current_price': 2.43,
#   'market_cap': 2070965884,
#   'market_cap_rank': 740,
#   'total_volume': 219085772,
#   'circulating_supply': 853631914.378197,
#   'total_supply': 853631914.378197,
#   'ath': 110.77,
#   'atl': 0.659872,
#   'last_updated': '2026-02-11T07:03:30.187Z'},
#  {'id': 'dia-data',
#   'symbol': 'dia',
#   'name': 'DIA',
#   'current_price': 17.28,
#   'market_cap': 2068952110,
#   'market_cap_rank': 741,
#   'total_volume': 173492961,
#   'circulating_supply': 119676104.0,
#   'total_supply': 168817248.0,
#   'ath': 423.11,
#   'atl': 15.34,
#   'last_updated': '2026-02-11T07:03:30.146Z'},
#  {'id': 'dkargo',
#   'symbol': 'dka',
#   'name': 'dKargo',
#   'current_price': 0.413672,
#   'market_cap': 2068338744,
#   'market_cap_rank': 737,
#   'total_volume': 45723318,
#   'circulating_supply': 5000000000.0,
#   'total_supply': 5000000000.0,
#   'ath': 51.01,
#   'atl': 0.382807,
#   'last_updated': '2026-02-11T07:03:30.189Z'},
#  {'id': 'konnect',
#   'symbol': 'kct',
#   'name': 'Konnect',
#   'current_price': 0.280073,
#   'market_cap': 2068159453,
#   'market_cap_rank': 739,
#   'total_volume': 43566025,
#   'circulating_supply': 7375000040.0,
#   'total_supply': 10000000000.0,
#   'ath': 12.12,
#   'atl': 0.00123459,
#   'last_updated': '2026-02-11T07:03:30.227Z'},
#  {'id': 'definitive',
#   'symbol': 'edge',
#   'name': 'Definitive',
#   'current_price': 10.16,
#   'market_cap': 2062479812,
#   'market_cap_rank': 743,
#   'total_volume': 126652626,
#   'circulating_supply': 203024680.07272866,
#   'total_supply': 1000000000.0,
#   'ath': 75.6,
#   'atl': 2.34,
#   'last_updated': '2026-02-11T07:03:30.323Z'},
#  {'id': 'black-phoenix',
#   'symbol': 'bpx',
#   'name': 'Black Phoenix',
#   'current_price': 0.356815,
#   'market_cap': 2058124408,
#   'market_cap_rank': 742,
#   'total_volume': 98.02,
#   'circulating_supply': 5768046430.488926,
#   'total_supply': 7929007945.284113,
#   'ath': 282.75,
#   'atl': 0.00010138,
#   'last_updated': '2026-02-11T06:29:46.645Z'},
#  {'id': 'sanctum-2',
#   'symbol': 'cloud',
#   'name': 'Cloud',
#   'current_price': 3.84,
#   'market_cap': 2056287879,
#   'market_cap_rank': 744,
#   'total_volume': 129330702,
#   'circulating_supply': 535679783.0,
#   'total_supply': 1000000000.0,
#   'ath': 52.79,
#   'atl': 3.48,
#   'last_updated': '2026-02-11T07:03:30.266Z'},
#  {'id': 'particle-network',
#   'symbol': 'parti',
#   'name': 'Particle Network',
#   'current_price': 8.79,
#   'market_cap': 2047797927,
#   'market_cap_rank': 745,
#   'total_volume': 804651646,
#   'circulating_supply': 233000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 35.76,
#   'atl': 3.86,
#   'last_updated': '2026-02-11T07:03:30.265Z'},
#  {'id': 'limitless-3',
#   'symbol': 'lmts',
#   'name': 'Limitless',
#   'current_price': 15.54,
#   'market_cap': 2045510152,
#   'market_cap_rank': 746,
#   'total_volume': 174099435,
#   'circulating_supply': 131598680.0,
#   'total_supply': 1000000000.0,
#   'ath': 60.89,
#   'atl': 4.4,
#   'last_updated': '2026-02-11T07:03:30.253Z'},
#  {'id': 'bifrost',
#   'symbol': 'bfc',
#   'name': 'Bifrost',
#   'current_price': 1.46,
#   'market_cap': 2035376251,
#   'market_cap_rank': 747,
#   'total_volume': 54247977,
#   'circulating_supply': 1391269925.662982,
#   'total_supply': 2368584074.0,
#   'ath': 57.84,
#   'atl': 1.19,
#   'last_updated': '2026-02-11T07:03:30.244Z'},
#  {'id': 'og-fan-token',
#   'symbol': 'og',
#   'name': 'OG Fan Token',
#   'current_price': 444.12,
#   'market_cap': 2035007689,
#   'market_cap_rank': 750,
#   'total_volume': 3113137563,
#   'circulating_supply': 4584551.0,
#   'total_supply': 5000000.0,
#   'ath': 2181.6,
#   'atl': 91.71,
#   'last_updated': '2026-02-11T07:03:30.271Z'},
#  {'id': 'huma-finance',
#   'symbol': 'huma',
#   'name': 'Huma Finance',
#   'current_price': 1.17,
#   'market_cap': 2023204962,
#   'market_cap_rank': 749,
#   'total_volume': 544160888,
#   'circulating_supply': 1733333333.0,
#   'total_supply': 10000000000.0,
#   'ath': 9.84,
#   'atl': 1.14,
#   'last_updated': '2026-02-11T07:03:30.183Z'},
#  {'id': 'celium',
#   'symbol': 'sn51',
#   'name': 'lium',
#   'current_price': 555.78,
#   'market_cap': 2023198809,
#   'market_cap_rank': 751,
#   'total_volume': 4939812,
#   'circulating_supply': 3633464.404357817,
#   'total_supply': 3633464.404357817,
#   'ath': 3198.81,
#   'atl': 550.85,
#   'last_updated': '2026-02-11T07:03:30.201Z'}]

# %%
import pandas as pd
coin_df = pd.DataFrame(records)
coin_df
# Out:
#                id symbol          name  current_price       market_cap  \
# 0         bitcoin    btc       Bitcoin     6045532.00  120852395422070
# 1        ethereum    eth      Ethereum      176448.00   21296838227583
# 2          tether   usdt        Tether          90.51   16689936562055
# 3          ripple    xrp           XRP         123.05    7497239093961
# 4     binancecoin    bnb           BNB       54250.00    7397643643204
# ..            ...    ...           ...            ...              ...
# 745   limitless-3   lmts     Limitless          15.54       2045510152
# 746       bifrost    bfc       Bifrost           1.46       2035376251
# 747  og-fan-token     og  OG Fan Token         444.12       2035007689
# 748  huma-finance   huma  Huma Finance           1.17       2023204962
# 749        celium   sn51          lium         555.78       2023198809
#
#      market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                  1  4.068008e+12        1.998746e+07  1.998746e+07
# 1                  2  1.938983e+12        1.206926e+08  1.206926e+08
# 2                  3  6.551301e+12        1.843940e+11  1.898610e+11
# 3                  4  2.234509e+11        6.091732e+10  9.998572e+10
# 4                  5  1.113127e+11        1.363595e+08  1.363595e+08
# ..               ...           ...                 ...           ...
# 745              746  1.740994e+08        1.315987e+08  1.000000e+09
# 746              747  5.424798e+07        1.391270e+09  2.368584e+09
# 747              750  3.113138e+09        4.584551e+06  5.000000e+06
# 748              749  5.441609e+08        1.733333e+09  1.000000e+10
# 749              751  4.939812e+06        3.633464e+06  3.633464e+06
#
#              ath          atl              last_updated
# 0    11187013.00  3993.420000  2026-02-11T07:03:20.755Z
# 1      431946.00    28.130000  2026-02-11T07:03:20.943Z
# 2         105.52    36.860000  2026-02-11T07:03:27.265Z
# 3         313.99     0.159343  2026-02-11T07:03:27.277Z
# 4      121422.00     2.580000  2026-02-11T07:03:31.968Z
# ..           ...          ...                       ...
# 745        60.89     4.400000  2026-02-11T07:03:30.253Z
# 746        57.84     1.190000  2026-02-11T07:03:30.244Z
# 747      2181.60    91.710000  2026-02-11T07:03:30.271Z
# 748         9.84     1.140000  2026-02-11T07:03:30.183Z
# 749      3198.81   550.850000  2026-02-11T07:03:30.201Z
#
# [750 rows x 12 columns]

# %%
coin_df['last_updated'] = pd.to_datetime(coin_df['last_updated']).dt.date
coin_df = coin_df.rename(columns={'last_updated': 'date'})
coin_df
# Out:
#                id symbol          name  current_price       market_cap  \
# 0         bitcoin    btc       Bitcoin     6045532.00  120852395422070
# 1        ethereum    eth      Ethereum      176448.00   21296838227583
# 2          tether   usdt        Tether          90.51   16689936562055
# 3          ripple    xrp           XRP         123.05    7497239093961
# 4     binancecoin    bnb           BNB       54250.00    7397643643204
# ..            ...    ...           ...            ...              ...
# 745   limitless-3   lmts     Limitless          15.54       2045510152
# 746       bifrost    bfc       Bifrost           1.46       2035376251
# 747  og-fan-token     og  OG Fan Token         444.12       2035007689
# 748  huma-finance   huma  Huma Finance           1.17       2023204962
# 749        celium   sn51          lium         555.78       2023198809
#
#      market_cap_rank  total_volume  circulating_supply  total_supply  \
# 0                  1  4.068008e+12        1.998746e+07  1.998746e+07
# 1                  2  1.938983e+12        1.206926e+08  1.206926e+08
# 2                  3  6.551301e+12        1.843940e+11  1.898610e+11
# 3                  4  2.234509e+11        6.091732e+10  9.998572e+10
# 4                  5  1.113127e+11        1.363595e+08  1.363595e+08
# ..               ...           ...                 ...           ...
# 745              746  1.740994e+08        1.315987e+08  1.000000e+09
# 746              747  5.424798e+07        1.391270e+09  2.368584e+09
# 747              750  3.113138e+09        4.584551e+06  5.000000e+06
# 748              749  5.441609e+08        1.733333e+09  1.000000e+10
# 749              751  4.939812e+06        3.633464e+06  3.633464e+06
#
#              ath          atl        date
# 0    11187013.00  3993.420000  2026-02-11
# 1      431946.00    28.130000  2026-02-11
# 2         105.52    36.860000  2026-02-11
# 3         313.99     0.159343  2026-02-11
# 4      121422.00     2.580000  2026-02-11
# ..           ...          ...         ...
# 745        60.89     4.400000  2026-02-11
# 746        57.84     1.190000  2026-02-11
# 747      2181.60    91.710000  2026-02-11
# 748         9.84     1.140000  2026-02-11
# 749      3198.81   550.850000  2026-02-11
#
# [750 rows x 12 columns]

# %%
coin_df.isnull().sum()
# Out:
# id                     0
# symbol                 0
# name                   0
# current_price          0
# market_cap             0
# market_cap_rank        0
# total_volume          14
# circulating_supply     0
# total_supply           2
# ath                    0
# atl                    0
# date                   0
# dtype: int64

# %%
coin_df = coin_df.dropna()
coin_df.isnull().sum()
# Out:
# id                    0
# symbol                0
# name                  0
# current_price         0
# market_cap            0
# market_cap_rank       0
# total_volume          0
# circulating_supply    0
# total_supply          0
# ath                   0
# atl                   0
# date                  0
# dtype: int64

# %%
coin_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pd.notnull(coin_df).sum().sum()
# Out:
# np.int64(8808)

# %%
coin_top = []
688271}, {'id': 'bitcoin', 'date': 1742428800000, 'price': 86815.44109470697}, {'id': 'bitcoin', 'date': 1742515200000, 'price': 84270.84358966233}, {'id': 'bitcoin', 'date': 1742601600000, 'price': 84009.532917822}, {'id': 'bitcoin', 'date': 1742688000000, 'price': 83793.30854192551}, {'id': 'bitcoin', 'date': 1742774400000, 'price': 85787.70914901773}, {'id': 'bitcoin', 'date': 1742860800000, 'price': 87327.72969669085}, {'id': 'bitcoin', 'date': 1742947200000, 'price': 87520.58391530563}, {'id': 'bitcoin', 'date': 1743033600000, 'price': 86960.8555491039}, {'id': 'bitcoin', 'date': 1743120000000, 'price': 87227.27158032371}, {'id': 'bitcoin', 'date': 1743206400000, 'price': 84359.46915506005}, {'id': 'bitcoin', 'date': 1743292800000, 'price': 82679.17255385047}, {'id': 'bitcoin', 'date': 1743379200000, 'price': 82356.38111183756}, {'id': 'bitcoin', 'date': 1743465600000, 'price': 82514.09365397849}, {'id': 'bitcoin', 'date': 1743552000000, 'price': 85237.5876052852}, {'id': 'bitcoin', 'date': 1743638400000, 'price': 82526.4221526433}, {'id': 'bitcoin', 'date': 1743724800000, 'price': 83163.98757387721}, {'id': 'bitcoin', 'date': 1743811200000, 'price': 83852.00765399594}, {'id': 'bitcoin', 'date': 1743897600000, 'price': 83595.88550177493}, {'id': 'bitcoin', 'date': 1743984000000, 'price': 78211.48358199988}, {'id': 'bitcoin', 'date': 1744070400000, 'price': 79179.29226757778}, {'id': 'bitcoin', 'date': 1744156800000, 'price': 76329.090356324}, {'id': 'bitcoin', 'dat ...

# %%
coin_top_df = pd.DataFrame(coin_top)
coin_top_df
# Out:
#            id           date         price
# 0     bitcoin  1739318400000  95739.977371
# 1     bitcoin  1739404800000  97836.188561
# 2     bitcoin  1739491200000  96561.663999
# 3     bitcoin  1739577600000  97488.481485
# 4     bitcoin  1739664000000  97569.951694
# ...       ...            ...           ...
# 1825   ripple  1770508800000      1.425215
# 1826   ripple  1770595200000      1.434969
# 1827   ripple  1770681600000      1.438898
# 1828   ripple  1770768000000      1.399761
# 1829   ripple  1770793544000      1.359442
#
# [1830 rows x 3 columns]

# %%
# Convert Unix Milliseconds to readable YYYY-MM-DD
coin_top_df['date'] = pd.to_datetime(coin_top_df['date'], unit='ms').dt.date
coin_top_df = coin_top_df.rename(columns={'id': 'coin_id', 'price': 'price_usd'})
coin_top_df
# Out:
#       coin_id        date     price_usd
# 0     bitcoin  2025-02-12  95739.977371
# 1     bitcoin  2025-02-13  97836.188561
# 2     bitcoin  2025-02-14  96561.663999
# 3     bitcoin  2025-02-15  97488.481485
# 4     bitcoin  2025-02-16  97569.951694
# ...       ...         ...           ...
# 1825   ripple  2026-02-08      1.425215
# 1826   ripple  2026-02-09      1.434969
# 1827   ripple  2026-02-10      1.438898
# 1828   ripple  2026-02-11      1.399761
# 1829   ripple  2026-02-11      1.359442
#
# [1830 rows x 3 columns]

# %%
coin_top_df.isnull().sum()
# Out:
# coin_id      0
# date         0
# price_usd    0
# dtype: int64

# %%
coin_top_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#OIL

oil_df = pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")

oil_df
# Out:
#              Date  Price
# 0      1986-01-02  25.56
# 1      1986-01-03  26.00
# 2      1986-01-06  26.53
# 3      1986-01-07  25.85
# 4      1986-01-08  25.87
# ...           ...    ...
# 10085  2026-01-27  62.04
# 10086  2026-01-28  62.75
# 10087  2026-01-29  64.77
# 10088  2026-01-30  64.50
# 10089  2026-02-02  61.60
#
# [10090 rows x 2 columns]

# %%
oil_df.to_csv("oil_prices.csv",index = False)
oil_df
# Out:
#              Date  Price
# 0      1986-01-02  25.56
# 1      1986-01-03  26.00
# 2      1986-01-06  26.53
# 3      1986-01-07  25.85
# 4      1986-01-08  25.87
# ...           ...    ...
# 10085  2026-01-27  62.04
# 10086  2026-01-28  62.75
# 10087  2026-01-29  64.77
# 10088  2026-01-30  64.50
# 10089  2026-02-02  61.60
#
# [10090 rows x 2 columns]

# %%
filtered_oil_df = oil_df.rename(columns={'Date': 'date', 'Price': 'price_usd'})
filtered_oil_df
# Out:
#              date  price_usd
# 0      1986-01-02      25.56
# 1      1986-01-03      26.00
# 2      1986-01-06      26.53
# 3      1986-01-07      25.85
# 4      1986-01-08      25.87
# ...           ...        ...
# 10085  2026-01-27      62.04
# 10086  2026-01-28      62.75
# 10087  2026-01-29      64.77
# 10088  2026-01-30      64.50
# 10089  2026-02-02      61.60
#
# [10090 rows x 2 columns]

# %%
filtered_oil_df.isnull().sum()
# Out:
# date         0
# price_usd    0
# dtype: int64

# %%
filtered_oil_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import yfinance as yf
import pandas as pd

# Choose indices
tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-01-12"


stocks_total = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")

stocks_total.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker             ^NSEI                                                      \
# Price               Open          High           Low         Close    Volume
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000  304100.0
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195  407700.0
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391  428800.0
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805  396500.0
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195  447800.0
#
# Ticker            ^IXIC                                                       \
# Price              Open         High          Low        Close        Volume
# Date
# 2020-01-01          NaN          NaN          NaN          NaN           NaN
# 2020-01-02  9039.459961  9093.429688  9010.889648  9092.190430  2.862700e+09
# 2020-01-03  8976.429688  9065.759766  8976.429688  9020.769531  2.586520e+09
# 2020-01-06  8943.500000  9072.410156  8943.500000  9071.469727  2.810450e+09
# 2020-01-07  9076.639648  9091.929688  9042.549805  9068.580078  2.381740e+09
#
# Ticker            ^GSPC
# Price              Open         High          Low        Close        Volume
# Date
# 1562   8.124420e+09   ^IXIC
#
# [1514 rows x 7 columns]

# %%
stocks_df3 = stocks_total['^NSEI'].reset_index().dropna()
stocks_df3['tickers'] = "^NSEI"
stocks_df3
# Out:
# Price       Date          Open          High           Low         Close  \
# 0     2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 1     2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2     2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391
# 3     2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805
# 4     2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195
# ...          ...           ...           ...           ...           ...
# 1558  2026-01-05  26333.699219  26373.199219  26210.050781  26250.300781
# 1559  2026-01-06  26189.699219  26273.949219  26124.750000  26178.699219
# 1560  2026-01-07  26143.099609  26187.150391  26067.900391  26140.750000
# 1561  2026-01-08  26106.500000  26133.199219  25858.449219  25876.849609
# 1562  2026-01-09  25840.400391  25940.599609  25623.000000  25683.300781
#
# Price    Volume tickers
# 0      304100.0   ^NSEI
# 1      407700.0   ^NSEI
# 2      428800.0   ^NSEI
# 3      396500.0   ^NSEI
# 4      447800.0   ^NSEI
# ...         ...     ...
# 1558   338800.0   ^NSEI
# 1559   383000.0   ^NSEI
# 1560   338200.0   ^NSEI
# 1561   328500.0   ^NSEI
# 1562   348800.0   ^NSEI
#
# [1493 rows x 7 columns]

# %%
stocks_df = pd.concat([stocks_df1, stocks_df2, stocks_df3], ignore_index = True)
stocks_df
# Out:
# Price       Date          Open          High           Low         Close  \
# 0     2020-01-02   3244.669922   3258.139893   3235.530029   3257.850098
# 1     2020-01-03   3226.360107   3246.149902   3222.340088   3234.850098
# 2     2020-01-06   3217.550049   3246.840088   3214.639893   3246.280029
# 3     2020-01-07   3241.860107   3244.909912   3232.429932   3237.179932
# 4     2020-01-08   3238.590088   3267.070068   3236.669922   3253.050049
# ...          ...           ...           ...           ...           ...
# 4516  2026-01-05  26333.699219  26373.199219  26210.050781  26250.300781
# 4517  2026-01-06  26189.699219  26273.949219  26124.750000  26178.699219
# 4518  2026-01-07  26143.099609  26187.150391  26067.900391  26140.750000
# 4519  2026-01-08  26106.500000  26133.199219  25858.449219  25876.849609
# 4520  2026-01-09  25840.400391  25940.599609  25623.000000  25683.300781
#
# Price        Volume tickers
# 0      3.459930e+09   ^GSPC
# 1      3.484700e+09   ^GSPC
# 2      3.702460e+09   ^GSPC
# 3      3.435910e+09   ^GSPC
# 4      3.726840e+09   ^GSPC
# ...             ...     ...
# 4516   3.388000e+05   ^NSEI
# 4517   3.830000e+05   ^NSEI
# 4518   3.382000e+05   ^NSEI
# 4519   3.285000e+05   ^NSEI
# 4520   3.488000e+05   ^NSEI
#
# [4521 rows x 7 columns]

# %%
stocks_df.isnull().sum()
# Out:
# Price
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# tickers    0
# dtype: int64

# %%
stocks_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (2.0.46)
# Requirement already satisfied: greenlet>=1 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\programdata\anaconda3\lib\site-packages (1.1.2)

# %%
import pymysql

# ---------------------------------------------------------
# 1. CONFIGURATION
# ---------------------------------------------------------
DB_CONFIG = {
    'host': 'localhost',
    'user': 'root',
    'password': 'Suba@2000',
    # NOTE: Do NOT include 'database' here yet!
}
DB_NAME = 'test_analysis2'  # Matches your error message


print(" Connecting to MySQL...")
# 1. Connect to MySQL Server (No specific DB)
conn = pymysql.connect(**DB_CONFIG)
cursor = conn.cursor()

# 2. Drop Database if it exists (Fresh Start)
print(f"  Dropping Database '{DB_NAME}' if it exists...")
cursor.execute(f"DROP DATABASE IF EXISTS {DB_NAME}")

# 3. Create Database
print(f"  Creating Database '{DB_NAME}'...")
cursor.execute(f"CREATE DATABASE {DB_NAME}")
print(" Database created!")

# 4. Select the new Database
conn.select_db(DB_NAME)

# 5. Create Tables
print(" Creating Tables...")

# Table 1: Cryptocurrencies
cursor.execute("""
    CREATE TABLE Cryptocurrencies (
        id VARCHAR(250) PRIMARY KEY,
        symbol VARCHAR(250),
        name VARCHAR(250),
        current_price DOUBLE,
        market_cap DOUBLE,
        market_cap_rank INT,
        total_volume DOUBLE,
        circulating_supply DOUBLE,
        total_supply DOUBLE,
        ath DOUBLE,
        atl DOUBLE,
        date DATE
    )
    """)
print("    Cryptocurrencies created")

# Table 2: Crypto_prices
cursor.execute("""
    CREATE TABLE Crypto_prices (
        coin_id VARCHAR(250),
        date DATE,
        price_usd DOUBLE,
        FOREIGN KEY (coin_id) REFERENCES Cryptocurrencies(id)
    )
    """)
print("    Crypto_prices created")

# Table 3: Oil_prices
cursor.execute("""
    CREATE TABLE Oil_prices (
        date DATE PRIMARY KEY,
        price_usd DECIMAL(18, 6)
    )
    """)
print("    Oil_prices created")

 # Table 4: Stock_prices
cursor.execute("""
    CREATE TABLE Stock_prices (
        date DATE,
        open DECIMAL(18, 6),
        high DECIMAL(18, 6),
        low DECIMAL(18, 6),
        close DECIMAL(18, 6),
        volume BIGINT,
        ticker VARCHAR(20)
    )
    """)
print("    Stock_prices created")

conn.close()
print("\n Database and Tables created successfully!")
# Out:
# 🔌 Connecting to MySQL...
# 🗑️  Dropping Database 'test_analysis2' if it exists...
# ⚙️  Creating Database 'test_analysis2'...
# ✅ Database created!
# 📝 Creating Tables...
#    ✅ Cryptocurrencies created
#    ✅ Crypto_prices created
#    ✅ Oil_prices created
#    ✅ Stock_prices created
#
# 🎉 Database and Tables created successfully!

# %%
import pymysql
import pandas as pd

# 1. Connect to MySQL
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='Suba@2000',
    database='test_analysis2'
)
cursor = connection.cursor()
print("Connected to database successfully!")

# ---------------------------------------------------------
# 1. UPLOAD CRYPTOCURRENCIES
# ---------------------------------------------------------
print("1. Uploading Cryptocurrencies (Row by Row)...")

columns_needed = ['id', 'symbol', 'name', 'current_price', 'market_cap', 
                  'market_cap_rank', 'total_volume', 'circulating_supply', 
                  'total_supply', 'ath', 'atl', 'date']
df_to_upload = coin_df[columns_needed].copy()


# SQL Command (INSERT IGNORE handles duplicates)
sql = """
INSERT IGNORE INTO Cryptocurrencies 
(id, symbol, name, current_price, market_cap, market_cap_rank, 
 total_volume, circulating_supply, total_supply, ath, atl, date) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Loop through each row and execute
data_list = [tuple(x) for x in df_to_upload.to_numpy()]
for row in data_list:
    cursor.execute(sql, row)

connection.commit()
print(f"   Done! ({len(data_list)} rows processed)")


# ---------------------------------------------------------
# 2. UPLOAD CRYPTO PRICES
# ---------------------------------------------------------
print("2. Uploading Crypto Prices (Row by Row)...")

prices_df = coin_top_df.rename(columns={'id': 'coin_id', 'price': 'price_usd'})

prices_df = prices_df[['coin_id', 'date', 'price_usd']]


sql = "INSERT IGNORE INTO Crypto_prices (coin_id, date, price_usd) VALUES (%s, %s, %s)"

data_list = [tuple(x) for x in prices_df.to_numpy()]
for row in data_list:
    cursor.execute(sql, row)

connection.commit()
print(f"   Done! ({len(data_list)} rows processed)")


# ---------------------------------------------------------
# 3. UPLOAD OIL PRICES
# ---------------------------------------------------------
print("3. Uploading Oil Prices (Row by Row)...")

oil_df = filtered_oil_df.rename(columns={'Date': 'date', 'Price': 'price_usd'})

oil_df = oil_df[['date', 'price_usd']]


sql = "INSERT IGNORE INTO Oil_prices (date, price_usd) VALUES (%s, %s)"

data_list = [tuple(x) for x in oil_df.to_numpy()]
for row in data_list:
    cursor.execute(sql, row)

connection.commit()
print(f"   Done! ({len(data_list)} rows processed)")


# ---------------------------------------------------------
# 4. UPLOAD STOCK PRICES
# ---------------------------------------------------------
print("4. Uploading Stock Prices (Row by Row)...")

stocks_clean = stocks_df.copy()

# Rename columns
stocks_clean = stocks_clean.rename(columns={
    'Date': 'date',
    'tickers': 'ticker',
    'Open': 'open',
    'High': 'high',
    'Low': 'low',
    'Close': 'close',
    'Volume': 'volume'
})

stocks_clean['date'] = pd.to_datetime(stocks_clean['date']).dt.date
final_stocks = stocks_clean[['date', 'open', 'high', 'low', 'close', 'volume', 'ticker']]


sql = """
INSERT IGNORE INTO Stock_prices (date, open, high, low, close, volume, ticker) 
VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

data_list = [tuple(x) for x in final_stocks.to_numpy()]
for row in data_list:
    cursor.execute(sql, row)

connection.commit()
print(f"   Done! ({len(data_list)} rows processed)")

# Close connection
connection.close()
print("\n  All uploads finished successfully!")
# Out:
# Connected to database successfully!
# 1. Uploading Cryptocurrencies (Row by Row)...
#    Done! (734 rows processed)
# 2. Uploading Crypto Prices (Row by Row)...
#    Done! (1830 rows processed)
# 3. Uploading Oil Prices (Row by Row)...
#    Done! (10090 rows processed)
# 4. Uploading Stock Prices (Row by Row)...
#    Done! (4521 rows processed)
#
# 🎉 All uploads finished successfully!
